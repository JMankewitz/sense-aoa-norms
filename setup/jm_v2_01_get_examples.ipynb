# %%
import sys
sys.path.append('../')

import pandas as pd
pd.options.mode.chained_assignment = None

import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer 
import random
import imp
from modules import data_cleaning

# %load_ext rpy2.ipython
import rpy2.robjects.lib.ggplot2 as ggplot2

# %%
import os
os.getcwd()
# Out:
# '/Users/jmankewitz/Projects/sense-aoa/setup'

# %%
# Get CDI
raw_cdi = pd.read_csv("../data/WSWG_50percentproducing.csv")
cdi_items = raw_cdi
# Fix Uni_Lemmas
import re
cdi_items['fixed_lemma'] = cdi_items['uni_lemma'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x))
cdi_items['fixed_lemma'] = cdi_items['fixed_lemma'].apply(lambda x: x.strip())
cdi_items['fixed_lemma']=cdi_items['fixed_lemma'].apply(lambda x: x.strip())

cdi_items.head(3)
# Out:
#    id                  word            language form  type        category  \
# 0   0  daddy (child's word)  English (American)   WG  word          people
# 1   1  mommy (child's word)  English (American)   WG  word          people
# 2   2                   bye  English (American)   WG  word  games_routines
#
#   lexical_category lexical_class uni_lemma  aoa_in_seconds  aoa fixed_lemma
# 0            other         other     daddy      29808000.0  345       daddy
# 1            other         other     mommy      30240000.0  350       mommy
# 2            other         other       bye      35164800.0  407         bye

# %%
raw_cdi[cdi_items['word'].str.contains("vanilla")]
# Out:
# Empty DataFrame
# Columns: [id, word, language, form, type, category, lexical_category, lexical_class, uni_lemma, aoa_in_seconds, aoa, fixed_lemma]
# Index: []

# %%
set(cdi_items.lexical_class)
# Out:
# {'adjectives', 'function_words', 'nouns', 'other', 'verbs'}

# %%
# lemmatize the fixed_lemmas just in case (looking @ you, "beads")
# Default to no pos specified if lexical_category is not retreivable
cdi_wordnet_pos_map = {"nouns": wn.NOUN,
                       "verbs": wn.VERB,
                       "adjectives": wn.ADJ}

lemmatizer = WordNetLemmatizer()

def lemmatizeLemma(lemma, proposed_pos):
    if proposed_pos in list(cdi_wordnet_pos_map.keys()):
        return lemmatizer.lemmatize(lemma, cdi_wordnet_pos_map[proposed_pos])
    else:
        return lemmatizer.lemmatize(lemma)

# fix glasses -> glass -> glassses, check for any more like this

cdi_items['lemmatized_lemma'] = cdi_items.apply(lambda row: lemmatizeLemma(row.fixed_lemma, row.lexical_class), axis=1)

#actually, this seems to cause more problems than it solves, so we'll use the fixed_lemma to match words

# %%
cdi_items.groupby(by=['fixed_lemma'])['lexical_category'].agg('nunique').reset_index().sort_values(by='fixed_lemma')
# Out:
#     fixed_lemma  lexical_category
# 0             a                 1
# 1         a lot                 1
# 2         after                 1
# 3      airplane                 1
# 4           all                 1
# ..          ...               ...
# 618       yucky                 1
# 619     yum yum                 1
# 620       zebra                 1
# 621      zipper                 1
# 622         zoo                 1
#
# [623 rows x 2 columns]

# %%
cdi_items[cdi_items['fixed_lemma']=='water']
# Out:
#     id                  word            language form  type    category  \
# 55  55      water (beverage)  English (American)   WS  word  food_drink
# 61  61  water (not beverage)  English (American)   WS  word     outside
#
#    lexical_category lexical_class             uni_lemma  aoa_in_seconds  aoa  \
# 55            nouns         nouns                 water      49161600.0  569
# 61            nouns         nouns  water (not beverage)      50544000.0  585
#
#    fixed_lemma lemmatized_lemma
# 55       water            water
# 61       water            water

# %%
restricted_pos_cdi = cdi_items[cdi_items['lexical_class'].isin(list(cdi_wordnet_pos_map.keys()))]
print(len(set(restricted_pos_cdi.fixed_lemma)),"words")
# Out:
# 455 words

# %%
lemmatizer.lemmatize("glasses")
[sense.name() for sense in wn.synsets("glass", 'n')]
# Out:
# ['glass.n.01',
#  'glass.n.02',
#  'glass.n.03',
#  'field_glass.n.01',
#  'methamphetamine.n.01',
#  'looking_glass.n.01',
#  'glass.n.07']

# %%
#first get all the senses for each word in the cdi
def getSensesFromLemma(lemma, pos):
    return [sense.name() for sense in wn.synsets(lemma, pos)]

cdi_wordnet_df = pd.DataFrame({'lemma':[], 'sense_name':[]})
#restrict to just nouns, verbs, adjectives
for word in restricted_pos_cdi.fixed_lemma:
    #get senses
    pos = cdi_wordnet_pos_map[list(restricted_pos_cdi[restricted_pos_cdi['fixed_lemma']==word].lexical_class)[0]]
    senses = getSensesFromLemma(word,pos)
    word_wordnet_df = pd.DataFrame({'sense_name':senses})
    word_wordnet_df['lemma'] = word
    cdi_wordnet_df = pd.concat([cdi_wordnet_df, word_wordnet_df])
    
cdi_wordnet_df = cdi_wordnet_df.reset_index(drop=True)
#then get the definitions and examples

# %%
cdi_wordnet_df[cdi_wordnet_df['lemma']=='glasses']
# Out:
#        lemma            sense_name
# 855  glasses       spectacles.n.01
# 856  glasses            glass.n.01
# 857  glasses            glass.n.02
# 858  glasses            glass.n.03
# 859  glasses      field_glass.n.01
# 860  glasses  methamphetamine.n.01
# 861  glasses    looking_glass.n.01
# 862  glasses            glass.n.07

# %%
cdi_wordnet_df['definition'] = cdi_wordnet_df.sense_name.apply(lambda sense_name: wn.synset(sense_name).definition())

# %%
cdi_wordnet_df['num_wn_examples'] = cdi_wordnet_df.sense_name.apply(lambda sense_name: len(wn.synset(sense_name).examples()))

# Cant default to just the first one, should default to an example that contains the word
def getWNExample(lemma, sense_name):
    possible_examples = wn.synset(sense_name).examples()
    acceptable_examples = [example for example in possible_examples if lemma in example]
    if len(acceptable_examples) == 0:
        return "no_example"
    else:
        return acceptable_examples[0]
    
cdi_wordnet_df['wn_example'] = cdi_wordnet_df.apply(lambda row: getWNExample(row.lemma, row.sense_name), axis=1)

# %%
print(len(cdi_wordnet_df[cdi_wordnet_df['wn_example']!='no_example']), "senses with acceptable examples")
print(len(cdi_wordnet_df[cdi_wordnet_df['wn_example']!='no_example'])/len(cdi_wordnet_df), "%")
print(len(cdi_wordnet_df[cdi_wordnet_df['wn_example']=='no_example']), "senses without examples")
print(len(cdi_wordnet_df[cdi_wordnet_df['wn_example']=='no_example'])/len(cdi_wordnet_df), "%")
# Out:
# 1567 senses with acceptable examples
# 0.5276094276094276 %
# 1403 senses without examples
# 0.4723905723905724 %

# %%
no_wn_example = cdi_wordnet_df[cdi_wordnet_df['wn_example']=='no_example']

cdi_wordnet_df[cdi_wordnet_df['wn_example']=='no_example']

#next pass is to pull from wordsense project or semcor for examples
# Out:
#       lemma  sense_name                                         definition  \
# 6      ball   ball.n.07  United States comedienne best known as the sta...
# 8      ball   ball.n.09             a lavish dance requiring formal attire
# 10     ball   ball.n.11                               the game of baseball
# 16      dog  frank.n.02  a smooth-textured sausage of minced beef or po...
# 17      dog   pawl.n.01  a hinged catch that fits into a notch of a rat...
# ...     ...         ...                                                ...
# 2962  stone  stone.n.08             United States filmmaker (born in 1946)
# 2963  stone  stone.n.09  United States feminist and suffragist (1818-1893)
# 2964  stone  stone.n.10  United States journalist who advocated liberal...
# 2965  stone  stone.n.11  United States jurist who served on the United ...
# 2966  stone  stone.n.12                United States architect (1902-1978)
#
#       num_wn_examples  wn_example
# 6                   0  no_example
# 8                   0  no_example
# 10                  0  no_example
# 16                  0  no_example
# 17                  0  no_example
# ...               ...         ...
# 2962                0  no_example
# 2963                0  no_example
# 2964                0  no_example
# 2965                0  no_example
# 2966                0  no_example
#
# [1403 rows x 5 columns]

# %% [markdown]
# ## Semcor examples

# %%
import nltk
from nltk.corpus import semcor
nltk.download('semcor')
# Out:
# [nltk_data] Downloading package semcor to
# [nltk_data]     /Users/jmankewitz/nltk_data...
# [nltk_data]   Package semcor is already up-to-date!
# True

# %%
def get_pos(lem, delim = '.'):
    """
    Inputs:
    lem- WordNet lemma
    delim- delimiting character (. or ,)
    Output:
    Part of speech for lem (n, v, s)
    """
    lem = str(lem)
    try:
        return lem.split(delim)[1]
    except:
        return 'No POS'

def get_sense_num(lem, delim = '.'):
    """
    DEPRECATED?
    Inputs: 
    lem- WordNet lemma
    delim- delimiting character (. or ,)
    Output:
    Number of sense in WordNet
    """
    lem = str(lem)
    try:
        return lem.split(delim)[2]
    except:
        return "No marked sense"

def get_name(lem, delim = '.'):
    """
    Inputs:
    lem- WordNet lemma
    delim- delimiting character (. or ,)
    Output:
    Name of sense in WordNet
    """
    if type(lem) != str:
        return lem.name()
    else:
        return lem.split(delim)[0]

# %%
tagged_sents = nltk.corpus.semcor.tagged_sents(tag = 'sem')[0:37176]
raw_sents = nltk.corpus.semcor.sents()[0:37176]

# %%
#restrict to sentences with the target lemmas
target_lemmas = set(no_wn_example.lemma)
target_tagged_sents = []
target_untagged_sents = []
for i in tqdm(np.arange(0, len(tagged_sents))):
    poss_sent = raw_sents[i]
    if not target_lemmas.isdisjoint(set(poss_sent)) and len(poss_sent)<15:
        target_tagged_sents.append(tagged_sents[i])
        target_untagged_sents.append(raw_sents[i])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=37176.0), HTML(value='')))

# %%
# for each tagged sentence in the reduced sentence list, check for a sense from my sense list

semcor_wn_senses = []
semcor_wn_sentences = []
for i in tqdm(np.arange(0, len(target_tagged_sents))):
    s = target_tagged_sents[i]
    for tok in s:
        if type(tok) == nltk.tree.Tree:
            tag_lemma = get_name(tok.label())
            tag_pos = get_pos(tok.label())
            tag_num = get_sense_num(tok.label())
            wn_sense_tag = tag_lemma+'.'+tag_pos+'.'+tag_num
            semcor_wn_senses.append(wn_sense_tag)
            #print(i, wn_sense_tag)
            clean_sentence = ''
            for item in target_untagged_sents[i]:
                clean_sentence+= item+' '
            semcor_wn_sentences.append(clean_sentence.strip())
            
sense_sentence_df = pd.DataFrame(data={'sense_name':semcor_wn_senses, 'semcor_sentence':semcor_wn_sentences})
#restrict to senses in the missing sense list
target_senses = sense_sentence_df[sense_sentence_df['sense_name'].isin(set(no_wn_example.sense_name))]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3347.0), HTML(value='')))

# %%
cdi_wordnet_df = pd.merge(cdi_wordnet_df,
                        target_senses,
                        left_on='sense_name',
                        right_on='sense_name',
                        how='left')
semcor_example_counts = target_senses.groupby(by=['sense_name'])['semcor_sentence'].agg('nunique').reset_index()
semcor_example_counts = semcor_example_counts.rename(columns={'semcor_sentence':'semcor_example_count'})

cdi_wordnet_df = pd.merge(cdi_wordnet_df,
                         semcor_example_counts,
                         left_on='sense_name',
                         right_on='sense_name',
                         how='left')
cdi_wordnet_df = cdi_wordnet_df.fillna(value={'semcor_sentence':'no_example', 'semcor_example_count':0})

cdi_wordnet_df.groupby(['sense_name', 'lemma']).agg(np.random.choice).reset_index()
# Out:
#         sense_name   lemma                                         definition  \
# 0     abridge.v.01     cut  reduce in scope while retaining essential elem...
# 1      absorb.v.04    draw                       take in, also metaphorically
# 2      accept.v.02    have       receive willingly something given or offered
# 3      accept.v.02    take       receive willingly something given or offered
# 4      accept.v.05    take                    admit into a group or community
# ...            ...     ...                                                ...
# 2882   yellow.s.03  yellow                changed to a yellowish color by age
# 2883   yellow.s.05  yellow             cowardly or treacherous; -M.W.Straight
# 2884    yield.v.01    give                          be the cause or source of
# 2885   yogurt.n.01  yogurt         a custard-like food made from curdled milk
# 2886    zebra.n.01   zebra  any of several fleet black-and-white striped A...
#
#       num_wn_examples                                         wn_example  \
# 0                   1                                         no_example
# 1                   2                                         no_example
# 2                   3  The only girl who would have him was the mille...
# 3                   3                                         no_example
# 4                   2                                         no_example
# ...               ...                                                ...
# 2882                1                                 yellowed parchment
# 2883                2                 the little yellow stain of treason
# 2884                2                                         no_example
# 2885                0                                         no_example
# 2886                0                                         no_example
#
#                                         semcor_sentence  semcor_example_count
# 0                                            no_example                   0.0
# 1                                            no_example                   0.0
# 2                                            no_example                   0.0
# 3                                            no_example                   0.0
# 4     Few new writers have their first story accepte...                   1.0
# ...                                                 ...                   ...
# 2882                                         no_example                   0.0
# 2883                                         no_example                   0.0
# 2884     Space probes have yielded little information .                   1.0
# 2885                                         no_example                   0.0
# 2886                                         no_example                   0.0
#
# [2887 rows x 7 columns]

# %%
cdi_wordnet_df = cdi_wordnet_df[['lemma', 'sense_name', 'definition', 'num_wn_examples', 'wn_example', 'semcor_example_count', 'semcor_sentence']]
cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & (cdi_wordnet_df['semcor_sentence']=='no_example')]
# Out:
#       lemma  sense_name                                         definition  \
# 6      ball   ball.n.07  United States comedienne best known as the sta...
# 8      ball   ball.n.09             a lavish dance requiring formal attire
# 10     ball   ball.n.11                               the game of baseball
# 16      dog  frank.n.02  a smooth-textured sausage of minced beef or po...
# 17      dog   pawl.n.01  a hinged catch that fits into a notch of a rat...
# ...     ...         ...                                                ...
# 4040  stone  stone.n.08             United States filmmaker (born in 1946)
# 4041  stone  stone.n.09  United States feminist and suffragist (1818-1893)
# 4042  stone  stone.n.10  United States journalist who advocated liberal...
# 4043  stone  stone.n.11  United States jurist who served on the United ...
# 4044  stone  stone.n.12                United States architect (1902-1978)
#
#       num_wn_examples  wn_example  semcor_example_count semcor_sentence
# 6                   0  no_example                   0.0      no_example
# 8                   0  no_example                   0.0      no_example
# 10                  0  no_example                   0.0      no_example
# 16                  0  no_example                   0.0      no_example
# 17                  0  no_example                   0.0      no_example
# ...               ...         ...                   ...             ...
# 4040                0  no_example                   0.0      no_example
# 4041                0  no_example                   0.0      no_example
# 4042                0  no_example                   0.0      no_example
# 4043                0  no_example                   0.0      no_example
# 4044                0  no_example                   0.0      no_example
#
# [1151 rows x 7 columns]

# %% [markdown]
# ## Still missing 1151 senses - Try CHILDES

# %%
# from the wordsense project! 
#for each word without a wordnet example look for a parent utterance from childes for the target senses
# need to get childes tags
# look for utterances with just the single tag for the target sense
# prioritize utterances with tags from multiple participants
# if there are more than 3, show all 3 and I can pick the best

# %%
from configs import postgres_config
from configs import mysql_config
from sqlalchemy import create_engine

wordsense_auth = postgres_config.Authenticator('WordSense')
ws_engine = create_engine(wordsense_auth.connectionString)

childesdb_auth  = mysql_config.Authenticator('ec2')
cdb_engine = create_engine(childesdb_auth.connectionString)

all_tags_df = pd.read_csv('../data/raw_tags.csv')
majority_token = pd.read_csv('../data/raw_majority_token_df.csv')
# Out:
# /Users/jmankewitz/Projects/envs/sense_aoa_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,14,15,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
derived_tokens_df = pd.read_sql_query('SELECT * from derived_tokens',ws_engine)
utterances = pd.read_sql_query('SELECT * from utterance where corpus_id=49', cdb_engine)
utterances_man = pd.read_sql_query('SELECT * from utterance where corpus_id=204', cdb_engine)
utterances = pd.concat([utterances, utterances_man])

# %%
tokens_w_one_tag = all_tags_df.groupby(by=['token_id'])['sense_name'].agg('nunique').reset_index()
tokens_w_one_tag = set(tokens_w_one_tag[tokens_w_one_tag['sense_name']==1].token_id.astype(int))

target_tags_df = majority_token[(majority_token['sense_name'].isin(set(no_wn_example.sense_name)))&
           majority_token['token_id'].isin(tokens_w_one_tag)]

target_tags_df = pd.merge(target_tags_df, derived_tokens_df[['id', 'utterance_id','speaker_role']], 
                         left_on='token_id',
                         right_on='id',
                         how='left')

target_tags_df = pd.merge(target_tags_df,
                         utterances[['id','gloss']],
                         left_on='utterance_id',
                         right_on='id',
                         how='left')

target_tags_df['lemma']= target_tags_df.type.apply(lambda word: word.split("+")[0])

# %%
parent_utterances = target_tags_df[target_tags_df['speaker_role']!='Target_Child']

# %%
def getChildesExamples(target_sense, utterances=parent_utterances):
    return parent_utterances[(parent_utterances['sense_name']==target_sense)][['utterance_id','gloss']]

# %%
cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & (cdi_wordnet_df['semcor_sentence']=='no_example')]
# Out:
#       lemma  sense_name                                         definition  \
# 6      ball   ball.n.07  United States comedienne best known as the sta...
# 8      ball   ball.n.09             a lavish dance requiring formal attire
# 10     ball   ball.n.11                               the game of baseball
# 16      dog  frank.n.02  a smooth-textured sausage of minced beef or po...
# 17      dog   pawl.n.01  a hinged catch that fits into a notch of a rat...
# ...     ...         ...                                                ...
# 4040  stone  stone.n.08             United States filmmaker (born in 1946)
# 4041  stone  stone.n.09  United States feminist and suffragist (1818-1893)
# 4042  stone  stone.n.10  United States journalist who advocated liberal...
# 4043  stone  stone.n.11  United States jurist who served on the United ...
# 4044  stone  stone.n.12                United States architect (1902-1978)
#
#       num_wn_examples  wn_example  semcor_example_count semcor_sentence
# 6                   0  no_example                   0.0      no_example
# 8                   0  no_example                   0.0      no_example
# 10                  0  no_example                   0.0      no_example
# 16                  0  no_example                   0.0      no_example
# 17                  0  no_example                   0.0      no_example
# ...               ...         ...                   ...             ...
# 4040                0  no_example                   0.0      no_example
# 4041                0  no_example                   0.0      no_example
# 4042                0  no_example                   0.0      no_example
# 4043                0  no_example                   0.0      no_example
# 4044                0  no_example                   0.0      no_example
#
# [1151 rows x 7 columns]

# %%
cdi_wordnet_df['num_childes_examples'] = cdi_wordnet_df.sense_name.apply(lambda sense_name: len(getChildesExamples(sense_name, target_tags_df)))
cdi_wordnet_df['childes_example'] = 'no_example'

# %%
def replaceChildesExample(string, sense_name):
    cdi_wordnet_df.loc[cdi_wordnet_df['sense_name'] == sense_name, 'childes_example'] = string
    return None

# %%
len(cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & 
                   (cdi_wordnet_df['semcor_sentence']=='no_example') &
                   (cdi_wordnet_df['childes_example']=='no_example') &
                  (cdi_wordnet_df['num_childes_examples']>0)])
# Out:
# 47

# %%
#manually pick through these examples from childes
target_senses = cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & 
                   (cdi_wordnet_df['semcor_sentence']=='no_example') &
                   (cdi_wordnet_df['childes_example']=='no_example') &
                  (cdi_wordnet_df['num_childes_examples']>0)].head(1)

print(list(target_senses['lemma'])[0])
print(list(target_senses['sense_name'])[0])
print(list(target_senses['definition'])[0])
print(' ')
for gloss in getChildesExamples(list(target_senses['sense_name'])[0], target_tags_df)['gloss']:
    print(gloss)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1471-21bfb342f79a> in <module>
#       4                   (cdi_wordnet_df['num_childes_examples']>0)].head(1)
#       5
# ----> 6 print(list(target_senses['lemma'])[0])
#       7 print(list(target_senses['sense_name'])[0])
#       8 print(list(target_senses['definition'])[0])
#
# IndexError: list index out of range

# %%
bad_example_str = 'no_good_example'
select_example = "Here's a tool bench"

# %%
replaceChildesExample(select_example, list(target_senses['sense_name'])[0])

# %%
replaceChildesExample(bad_example_str, list(target_senses['sense_name'])[0])

# %%
len(set(cdi_wordnet_df.sense_name))
# Out:
# 2729

# %%
#get senses with wordnet examples
cdi_wordnet_df = cdi_wordnet_df.groupby(['sense_name', 'lemma']).agg(np.random.choice).reset_index()

wn_examples = cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']!='no_example')]
wn_examples['example'] = wn_examples['wn_example']
wn_examples['example_source'] = 'wordnet'

#get senses without wordnet senses that do have semcor senses
semcor_examples = cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & 
                                    (cdi_wordnet_df['semcor_sentence']!='no_example') ]

semcor_examples['example'] = semcor_examples['semcor_sentence']
semcor_examples['example_source'] = 'semcor'

#get senses without semcor or childes senses that do have childes
childes_examples = cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & 
                                    (cdi_wordnet_df['semcor_sentence']=='no_example') &
                                    (~cdi_wordnet_df['childes_example'].isin(['no_example','no_good_example']))]

childes_examples['example'] = childes_examples['childes_example']
childes_examples['example_source'] = 'childes'

#get senses without any example
no_examples = cdi_wordnet_df.loc[(cdi_wordnet_df['wn_example']=='no_example') & 
                                    (cdi_wordnet_df['semcor_sentence']=='no_example') &
                                    (cdi_wordnet_df['childes_example'].isin(['no_example','no_good_example']))]
no_examples['example'] = 'no_example'
no_examples['example_source'] = 'no_example'

#merge back together
target_columns=['lemma', 'sense_name', 'definition', 
                'example', 'example_source']
examples_df = pd.concat([wn_examples[target_columns], semcor_examples[target_columns],
         childes_examples[target_columns], no_examples[target_columns]])

# %%
examples_df.to_csv("sense_examples_from_corpora.csv")

# %%
examples_df = pd.read_csv("sense_examples_from_corpora.csv")
examples_df.groupby(by=['example_source'])['sense_name'].agg('nunique')
# Out:
# example_source
# childes            264
# hand_written       283
# no_example          52
# previous_study     446
# semcor             219
# wordnet           1544
# Name: sense_name, dtype: int64

# %% [markdown]
# ## Now use the examples from the previous qualtrics

# %%
raw_word_sense_text_entry_df = pd.read_csv('../data/word_sense_text_entry_most.csv',dtype=str)
word_sense_text_entry_df = raw_word_sense_text_entry_df[raw_word_sense_text_entry_df['Q3']=='I consent to participate in this study.']
question_dict = raw_word_sense_text_entry_df.loc[0].to_dict()

sense_survey = pd.read_csv("final_sense_survey.csv")

# %%
sense_survey[sense_survey['wordnet_sense']=='slide_fastener.n.01']
question_dict['zipper n_say_1']
# Out:
# 'Please enter your best estimate of the first age (in numbers) by which you think a child would say the word [ zipper ] to express it in each of the following ways: - a fastener for locking together two toothed edges by means of a sliding tab ( EXAMPLE(s): The zipper on my jacket broke  )'

# %%
sense_question_to_wn_map = pd.read_csv('sense_question_to_wn_map.csv')

# %%
sense_question_to_wn_map['question_word'] = sense_question_to_wn_map.sense_question.apply(lambda ques: ques.split(" ")[0])

# %%
import string

examples_df[examples_df['example_source']=='no_example']
def getExampleFromQuestion(lemma, sense_name):
    question_conversion = sense_question_to_wn_map[sense_question_to_wn_map['wordnet_sense']==sense_name]
    target_question = ''
    if len(question_conversion) == 0:
        return 'no_example'
    elif len(question_conversion) > 1:
        restricted_question_conversion = question_conversion[question_conversion['question_word']==lemma]
        if len(restricted_question_conversion) <1:
            return 'no_example'
        else:
            target_question = list(restricted_question_conversion.sense_question)[0]
    else:
        target_question = list(question_conversion.sense_question)[0]
    
    full_question = question_dict[target_question]
    match_example = re.search('(?<=\( EXAMPLE\(s\)\:).*', full_question)
    match_example = str(match_example.group()).strip()
    match_example = match_example.strip(string.punctuation).replace('"', '').replace("`","'").strip()
    return match_example

# %%
missing_examples = examples_df[examples_df['example']=='no_example']
missing_examples['example'] = missing_examples.apply(lambda row: getExampleFromQuestion(row.lemma, row.sense_name), axis=1)
missing_examples.loc[missing_examples['example'] != 'no_example', 'example_source'] = 'previous_study'

#z['c'] = z.apply(lambda x: math.log(x.b) if x.b > 0 else 0, axis=1)

# %%
examples_df = pd.concat([missing_examples, examples_df[examples_df['example']!='no_example']])
examples_df
# Out:
#        lemma      sense_name  \
# 277   better      adept.s.01
# 280    windy       airy.s.02
# 282    touch     allude.v.01
# 283     jump  alternate.v.01
# 284      dog    andiron.n.01
# ...      ...             ...
# 2882     cut  write_out.v.02
# 2883    yard       yard.n.02
# 2884    yard       yard.n.03
# 2885  yellow     yellow.s.03
# 2886  yellow     yellow.s.05
#
#                                              definition  \
# 277   having or showing knowledge and skill and apti...
# 280            not practical or realizable; speculative
# 282          make a more or less disguised reference to
# 283   go back and forth; swing back and forth betwee...
# 284              metal supports for logs in a fireplace
# ...                                                 ...
# 2882                                 make out and issue
# 2883  the enclosed land around a house or other buil...
# 2884  a tract of land enclosed for particular activi...
# 2885                changed to a yellowish color by age
# 2886             cowardly or treacherous; -M.W.Straight
#
#                                                example  example_source
# 277     She's better at computer science than the rest  previous_study
# 280                                         no_example      no_example
# 282   He touched on the problem but did not mention it  previous_study
# 283                He kept jumping in and out of focus  previous_study
# 284                                         no_example      no_example
# ...                                                ...             ...
# 2882                                      cut a ticket         wordnet
# 2883          it was a small house with almost no yard         wordnet
# 2884     they opened a repair yard on the edge of town         wordnet
# 2885                                yellowed parchment         wordnet
# 2886                the little yellow stain of treason         wordnet
#
# [2887 rows x 5 columns]

# %%
examples_df.groupby(by=['example_source']).size().reset_index()
# Out:
#    example_source     0
# 0         childes   272
# 1    hand_written     8
# 2      no_example   209
# 3  previous_study   631
# 4          semcor   246
# 5         wordnet  1521

# %%
examples_df = pd.read_csv("sense_examples_from_corpora.csv")

# %%
examples_df.groupby(by=['example_source']).size().reset_index()
# Out:
#    example_source     0
# 0         childes   267
# 1    hand_written   291
# 2      no_example    53
# 3  previous_study   454
# 4          semcor   229
# 5         wordnet  1593

# %%
wn.synset('airplane.n.01').examples()
# Out:
# ['the flight was delayed due to trouble with the airplane']

# %%
def checkExamples(sense_name, curr_example, curr_source):
    if curr_source == 'previous_study':
        if curr_example in wn.synset(sense_name).examples():
            return "wordnet"
        else:
            return "new_hand_written"
    else:
        return curr_source

# %%
examples_df.example_source = examples_df.apply(lambda row: checkExamples(row.sense_name, row.example, row.example_source),
                                               axis=1)

# %%
examples_df.groupby(by=['example_source']).size().reset_index()
# Out:
#      example_source     0
# 0           childes   267
# 1      hand_written   291
# 2  new_hand_written   367
# 3        no_example    54
# 4            semcor   229
# 5           wordnet  1679

# %%
def fixNoExample(example, example_source):
    if example == 'no_example':
        return "no_example"
    else:
        return example_source

# %%
examples_df = examples_df.fillna({"example":'no_example'})

# %%
examples_df.example_source = examples_df.apply(lambda row: fixNoExample(row.example, row.example_source), axis=1)

# %%
def containsWord(lemma, definition):
    print(lemma, definition)
    if lemma in definition:
        return True
    else:
        return False

# %%
examples_df['contains_word'] = examples_df.apply(lambda row: containsWord(row.lemma, row.example), axis=1)
# better no_example
# better She has a better relationship with her sister than her brother
# better They're better off after the new job
# better Ruined the family's better name
# better A better mile from here
# better It was such a better experience
# better She's a much better person than everyone else
# better It was a better explanation
# better It's better than I stayed in
# better The Mona Lisa is one of his better paintings
# better Jazz is better music than R&B
# better It is better to eat salads than fast foods
# better The meat is better before the expiration date
# better Many people think Pop music is better than any other genre
# better I'm feeling much better
# better It would be better to speak to him
# better You say God make my knee better
# better I need a better hammer
# better I try to be a better man
# better I think this is a better tool for the job
# better You're a better man than I am, Gunga Din
# better her health is better now
# better it would be better to speak to him
# better argued for the better part of an hour
# bib Can I just put your bib back on
# bib The baby's got a bib on
# bicycle he steered his bicycle.
# big In an instant she was back in her bedroom like a big girl again
# big in a big rage
# big graduation was a big day in his life
# big a big voice
# big a big figure in the movement
# big big spender
# big too big for his britches
# big a big wind
# big a heart big enough to hold no grudges
# big was a big tipper
# big she was big with child
# big big talk
# big set out for the big city
# bird Do you want to eat bird?
# bird He made a bird from the jumpscare
# bird She hated being called a bird
# bird Throw the bird back, exclaimed the player
# bird wild birds crowding the air
# bite The sun bit his face
# bite The fork bit into the surface
# bite A bee bit my arm yesterday
# bite Gunny invariably tried to bite her
# black I like my coffee black
# black This must have been Hudson 's blackest discovery.
# black black leather jackets
# black a great people, a black people, injected new meaning and dignity into the veins of civilization
# black black looks
# black the future looked black
# black black deeds
# black a face black with fury
# black a black moonless night
# black black humor
# black black propaganda
# black Man has written one of his blackest records as a destroyer on the oceanic islands
# black with feet black from playing outdoors
# black the black economy pays no taxes
# blanket no_example
# blanket From under the shapeless huddle of blanket the feet moved
# blanket there was a blanket of snow
# block Basketball players need to block their opponents when playing defense
# block You need to use the block to open the curtains
# block Should we make a house with the blocks
# block they put their paintings on the block
# block the pyramids were built with large stone blocks
# block he lives in the next block
# block he reserved a large block of seats
# block there is a block of classrooms in the west wing
# block since blocks are often defined as a single sector, the terms `block' and `sector' are sometimes used interchangeably
# block I knew his name perfectly well but I had a temporary block
# block we had to call a plumber to clear out the blockage in the drainpipe
# block the engine had to be replaced because the block was cracked
# blow You're going to blow all your savings if you keep this up
# blow The whistle blew
# blow The trumpets blew
# blow Blow my hair dry
# blow The whales blew
# blow The lightbulds blew out
# blow She likes to blow about her achievements in college
# blow I blew the dinner so we had to eat out
# blow She blew him yesterday
# blow The children blew along
# blow He blew his inheritance on his insincere friends
# blow When the wind blows, the cradle will rock
# blow Mummy blew it up didn't she and it burst
# blow blow the flute
# blow The wind blew them all over
# blow Don't blow a gasket
# blow blow on the soup to cool it down
# blow blow one's nose
# blow certain insects are said to blow
# blow The double agent was blown by the other side
# blow blow a horse
# blow The leaves were blowing in the wind
# blue no_example
# blue a blue family
# blue blue language
# blue October's bright blue weather
# blue a ragged blue line
# blue a blue movie
# blue a blue day
# blue lonely and blue in a strange city
# boat Pass me the gravy boat please
# boat That boat in the river
# book What is your favorite passage from The Book?
# book no_example
# book We need to be off book by Thursday
# book The Holy Book of Islam is also known as the Quran
# book I am reading a good book on economics
# book he used a large book as a doorstop
# book they run things by the book around here
# book the book of Isaiah
# book he bought a book of stamps
# book they got a subpoena to examine our books
# book his name is in all the record books
# boots What a boot!
# boots no_example
# boots no_example
# boots Put the luggage in the boot
# boots He wore a boot for his broken ankle
# boots The plank floor was slimed beneath Watson 's boots
# boots She gave him the boot
# bottle Would you like a bottle of water?
# bottle I think that's the baby's bottle
# bottle On unoccupied roadway the bottle shattered into a small amber flash .
# bowl Shape your hands like a bowl
# bowl Lawn bowl ball
# bowl Can I get a bowl for my cigar?
# bowl Bowling ball
# bowl He had a perfect bowl
# bowl There's more soup in the bowl
# bowl You've got two spoons and two bowls
# bowl Alex ate a bowl
# bowl The rose bowl
# box The garden was full of boxes
# box his lying got him into a tight box
# box he rummaged through a box of spare parts
# box the royal box was empty
# box he gave her a box of chocolates
# box the flowchart contained many boxes
# box the umpire warned the batter to stay in the batter's box
# box an armed guard sat in the box with the driver
# box the sentry stayed in his box to avoid the cold
# box I gave him a good box on the ear
# bread Let's get this bread
# bread Do you want bread and jam or a couple letter cookies?
# break Lets break for lunch
# break The ranks broke
# break I refuse to break, even under torture
# break The clouds broke after the heavy downpour
# break Light broke over the horizon
# break The surf broke
# break The heat wave finally broke yesterday
# break She finally broke herself of smoking cigarettes
# break The first winter storm broke over New York
# break The skateboarder broke and nearly hit the pedestrian
# break The whales broke
# break It was his turn to break in this game of pool
# break The referee broke the boxers
# break The lawn mower finally broke
# break The skin broke
# break The blade broke her skin
# break News of her death broke in the morning
# break The simple vowels broke in many Germanic languages
# break Her voice broke to a whisper when she started to talk about her children
# break Things have been breaking pretty well for us in the past few months
# break Stock prices broke
# break The patient's fever broke last night
# break The flat plain was broken by tall mesas
# break The will was broken
# break He was broken down to Sergeant
# break The dam broke
# break The figurine broke
# break The car broke down
# break I broke my foot while playing hockey
# break My friend and I broke up
# break He broke the news to her
# break break a law
# break Violet that will break the markers and you won't be able to use them
# break I'm gonna put some graham crackers in this bag and I want you to break them up into little pieces okay
# break Earthquakes result when movements in the earth twist rocks until they break.
# break How can the vicious circle be broken?
# break My house was broken into
# break My daughter's fancy wedding is going to break me!
# break break a record
# break Nobody can break out--this prison is high security
# break break into tears
# break break off the negotiations
# break If the new teacher won't break, we'll add some stress
# break break cigarette smoking
# break Things have been breaking pretty well for us in the past few months
# break This play will either make or break the playwright
# break I had to break a $100 bill just to buy the candy
# break The book dealer would not break the set
# break break a branch from a tree
# break break a circuit
# break break an alibi
# break break the code
# break his voice is breaking--he should no longer sing in the choir
# break Kids were break-dancing at the street corner
# break The horse was tough to break
# break break a fall
# break break a lucky streak
# break let's break for lunch
# break break a law
# bring The noise and the screaming brought the curious
# bring The confession of one of the accused brought the others to admit to the crime as well
# bring The painting brought $10,000
# bring It brought men out of bed and sent them into hurried conferences
# bring This brings me to the main point
# bring bring water to the boiling point
# bring bring comments
# bring Could you bring the wine?
# bring Can I bring my cousin to the dinner?
# bring bring charges
# bring She brings a special atmosphere to our meetings
# broken a broken mirror
# broken broken lines of defense
# broken broken (or unkept) promises
# broken a broken man
# broken a horse broken to the saddle
# broken broken terrain
# broken broken English
# broken troops fleeing in broken ranks
# broken broken health resulting from alcoholism
# broken the broken fortunes of the family
# broken a broken washing machine
# broken broken clouds
# broken a broken set of encyclopedia
# broom Get the broom and clean up this mess
# broom Brooms tolerate poor soils and growing conditions
# broom The broom tree is a desert shrub
# brown His skin turned brown from being in the sun for too long
# brown brown cow
# brush The car brushed against the curb
# brush The fox has a nice brush
# brush The brothers always have brushes with each other
# brush usually electric motors have a brush
# brush On their right rose the embankment covered with brush and trees .
# brush I need a detangling brush
# brush the dentist recommended two brushes a day
# brush he gave his hair a quick brush
# brush I had a brush with danger on my way to work
# bubbles he didn't want to burst the newcomer's bubble
# bubbles The bar was in a bubble on the lawn at the party
# bubbles Don't you think this plan is a bit of a bubble?
# bubbles That pig wants to have a bath with bubbles
# bucket Those are pails or buckets, you can call them either a pail or a bucket
# bucket You want to draw buckets of water?
# bug There is a bug in my laptop, can you fix it?
# bug Hid the bug in the plant so they won't know that we are listening
# bug Those bugs are so scary
# bug I hope you do not have a stomach bug
# bug I don't think that's a bug I think it's a speck of dirt
# build He built our house
# build build a reputation
# build build detergents
# build The government is building new schools in this state
# build build a modern nation
# build These architects build in interesting and new styles
# build build a defense on nothing but the accused person's reputation
# build Suspense was building right from the beginning of the opera
# build Pressure is building up at the Indian-Pakistani border
# build build up confidence
# bump She was bumped because she always speaks up
# bump The new employee bumped her by moving into her office space
# bump Great to bump into you
# bump My car bumped into the tree
# bump bump and grind
# bunny She was almost a Playboy Bunny
# bunny Then the little bunny started to eat a leaf
# bus A bus is when all the nodes are connected to a single cable.
# bus he always rode the bus to work
# bus the fenders had fallen off that old bus
# bus the busbar in this computer can transmit data either way between any two components of the system
# butt A butt cracked and the storeroom flooded
# butt the butt of a knife
# butt The butt of the carrot looks healthy
# butt He was the butt of all the jokes
# butt Cigarette butt
# butt Make sure the butt joints are secure
# butt Smoking a butt
# butt the competitor must shoot butts at ranges of 75 to 200 yards
# butt he deserves a good kick in the butt
# butter Keep your hands up around that one, he's a butter
# butter you wanna have some of that bread that you had yesterday with the butter on it
# butterfly I saw a beautiful butterfly in the garden.
# butterfly He did a butterfly stroke.
# button My mom loves button flowers
# button Press the pause button
# button no_example
# button push the button and it pops up
# button her button popped off
# button they passed out campaign buttons for their candidate
# button the elevator was operated by push buttons
# buy This judge can be bought
# buy I need to buy some eggs
# buy This sum will buy you a ride on the train
# buy She wanted to buy his love with her dedication to him and his work
# buy I can't buy this story
# cake cake of soap
# cake a cake of meatballs
# cake I've got a birthday cake here
# camera Say bye bye to the camera
# camera I bought a camera to take pictures of plants
# can he deserves a good kick in the can
# can I ate a can of beans
# can There are cans near the shore to signal navigation
# can There are no public cans here
# can I have to hit the can
# can He considered opening a can of beer
# candy I love candy and sweets
# car The car of the airship
# car they took a cable car to the top of the mountain
# car he needs a car to get to work
# car three cars had jumped the rails
# car the car was on the top floor
# careful She was careful and graceful when walking
# careful they were careful when crossing the busy street
# careful careful of her feelings
# careful Thou art careful and troubled about many things
# careful careful with money
# carrots We will harvest the carrots soon
# carrots We plant carrots in our garden
# carrots Horses love carrots
# carrots used the carrot of subsidized housing for the workers to get their vote
# chicken You're such a chicken, just do it!
# chicken The chicken says bock bock bock
# chicken `` Chicken '' , Mose said , and theatrically licked his lips .
# chin no_example
# chin Half of it dripped down his chin .
# chips A chip of rock cuaght him in the eye
# chips These chips are used in throwing contests
# chips There's a chip in this mug
# chips Potato chip
# chips After winning, he threw a chip to the bartender as a tip
# chips A computer chip
# chips A chip shot
# chips He made a chip on the bark of the tree
# chips The chip log is used to measure the speed of a ship through water
# chips Fish and chips
# chocolate The wall was a deep chocolate
# chocolate I went and bought a box of chocolates for them to say thank you
# chocolate Do you want some more hot chocolate
# clap His dad clapped his back after he made the goal
# clap The big audience started applauding even before he had finished .
# clap The judge clapped him in jail
# clap The big bird clapped its wings
# clap The children were clapping to the music
# clap the wings of the birds clapped loudly
# clap clap two boards together
# clean I searched them, they're clean
# clean He was listening to the clean version of the song
# clean a clean page
# clean children with clean shining faces
# clean a clean fuel
# clean good clean fun
# clean a clean bill of health
# clean efforts to obtain a clean bass in orchestral recordings
# clean clean water
# clean a clean voting record
# clean led a clean life
# clean a clean manuscript
# clean a clean fight
# clean a clean test flight
# clean a clean getaway
# clean he landed a clean left on his opponent's cheek
# clean after a long dependency on heroin she has been clean for 4 years
# clean a clean (or uninfected) wound
# climb He's gonna to climb on top of the buildings
# climb Did you ever climb up the hill behind your house?
# climb The path climbed all the way to the top of the hill
# climb This young man knows how to climb the social ladder
# climb prices climbed steeply
# climb Sales were climbing after prices were lowered
# clock If only there was a clock for him to crawl against .
# close Close that tab
# close He closed his stance towards the target
# close She had , she said , heard that the plant was closing .
# close The windows closed with a loud bang
# close The meeting was closed with a charge by the chairman of the board
# close We closed on the house on Friday
# close The stock market closed high this Friday
# close close with the enemy
# close Her arms closed around her long lost relative
# close The probe closed with the space station
# close Management closed ranks
# close Due to the accident, the road had to be closed for several hours
# close Can you close the cracks with caulking?
# close The relief pitcher closed with two runs in the second inning
# close The owners decided to move and to close the factory
# close close the circuit
# close The concert closed with a nocturne by Chopin
# closet He prays in the closet
# closet Hang your clothes in the closet
# closet The water closet is down the hall
# closet In the kitchen Mama was wiping the cupboards .
# cloud Behind him billowed a small pungent cloud of smoke .
# cloud Early in November the clouds lifted enough to carry out the assigned missions .
# cloud his head was in the clouds
# cloud the only cloud on the horizon was the possibility of dissent by the French
# cloud after that mistake he was under a cloud
# cloud clouds of blossoms
# coat The dog has a thick coat
# coat `` This coat looks like a rag heap '' .
# coat a second coat of paint
# coffee The wall was a dark coffee
# coffee There is a field of coffee trees over there
# coffee A buy my own coffee beans
# coffee he ordered a cup of coffee
# coke He was arrested for a baggie of coke
# coke no_example
# coke drinking his coke through a straw
# cold Playing Hot and Cold, he only got colder
# cold The relationship turned cold
# cold a cold climate
# cold a cold unfriendly nod
# cold a cold trail
# cold a cold bluish grey
# cold had her lines cold before rehearsals started
# cold cold fury gripped him
# cold was cold to his advances
# cold in cold blood
# cold a cold audience
# cold the boxer was out cold
# cold cold in his grave
# comb The turkey's comb
# comb There are special combs for animal grooming
# comb no_example
# comb Now get your comb and your razor and all your styling supplies
# comb his hair needed a comb
# cook I have to cook your toast
# cut soap cuts grease
# cut This cuts into my earnings
# cut cut the noise
# cut The baby cut a tooth
# cut The new tooth is cutting
# cut cut bourbon
# cut cut recording tape
# cut she could not cut the long days in the office
# cut She cut him dead at the meeting
# cut The employer wants to cut back health benefits
# cut The car cut to the left at the intersection
# cut cut the engine
# cut cut a ticket
# cute a cute kid with pigtails
# cute a child with intolerably cute mannerisms
# dance The young girl danced into the room
# dance My husband and I like to dance at home to the radio
# dance The children danced with joy
# dark the dark ages
# dark Darth Vader of the dark side
# dark the dark days of the war
# dark dark-skinned peoples
# dark sitting in a dark corner
# dark dark green
# dark dark eyes
# dark keep it dark
# dark a dark scowl
# dark much that was dark is now quite clear to me
# dark the theater is dark on Mondays
# deer He conjures herds of deer , and wild birds crowding the air .
# diaper no_example
# diaper She doesn't have a diaper on
# dirty a dirty fighter
# dirty dirty unswept sidewalks
# dirty dirty words
# dirty the air near the foundry was always dirty
# dirty a dirty (or lousy) trick
# dirty dirty wounds
# dirty dirty
# dirty foul (or dirty) copy
# dirty dirty money
# dirty dirty looks
# dirty dirty police officers
# dirty there's dirty weather in the offing
# dish We have satelite dish on our roof
# dish What a dish
# dish marriage was scarcely his dish
# dish we gave them a set of dishes for a wedding present
# dish she prepared a special dish for dinner
# dish they served me a dish of rice
# dog The cinder remains of the firewood rested on the dog.
# dog no_example
# dog Hot dogs are my favorite food
# dog you dirty dog
# dog the dog barked all night
# dog you lucky dog
# dog she's a real dog
# doll Darling would you be a doll?
# doll Shall we put this dress on the doll
# donkey A Donkey like you just wouldn't understand
# donkey A donkey says hee-haw very good
# donut What if they don't have sprinkle donuts would you like a different kind?
# door he knocked on the door
# door we closed the door to Haitian immigrants
# door the office next door
# door his office is the third door down the hall on the left
# door he stuck his head in the doorway
# draw The store owner was happy that the ad drew in many new customers
# draw he drew strength from the minister's words
# draw The comdedian drew a lot of laughter
# draw The ship drew near the shore
# draw He drew a base on balls
# draw The nurse drew blood
# draw The material drew after it was washed in hot water
# draw Draw blood and pus
# draw The cart was drawn by an ox
# draw He drew great benefits from his membership in the association
# draw The child drew glass beads on a string
# draw She drew $2000 from the account
# draw I can't draw a monkey I don't know what a monkey looks like
# draw Those ducks better watch out so the bicycles don't run them over
# draw Oh I think we drew then didn't we
# draw A second explanation is suggested by the material described in Rowlands ' paper .
# draw He unlashed the dipper and drew water from a barrel .
# draw draw a chicken
# draw I draw a line here
# draw draw a weapon
# draw The participants in the experiment were drawn from a representative population
# draw draw a card
# draw She was drawn to despair
# draw The deed was drawn in the lawyer's office
# draw He spent the day drawing in the garden
# draw draw the shades
# draw This chimney draws very well
# draw This boat draws 70 inches
# draw in the old days, people were drawn and quartered for certain crimes
# draw draw wire
# draw draw pulp from the fruit
# draw draw steel
# draw draw a deep breath
# draw draw a wagon
# draw The archers were drawing their bows
# draw draw a line
# drawer no_example
# drawer I know but Daddy's the drawer not me
# drawer Mom could you please grab the screw driver out of the drawer?
# dress Elena , you 'll get mud all over your dress '' !
# dress fastidious about his dress
# dress battle dress
# drink Many food and beverage companies are already on a highly planned basis .
# drink I asked for a hot drink
# drink drink was his downfall
# drink he jumped into the drink and had to be rescued
# drink he took a drink of his beer and smacked his lips
# drive She finally drove him to change jobs
# drive What are you driving at?
# drive The car drove around the corner
# drive Drive back the urge to smoke
# drive We have to drive a little to make the deadline
# drive Why do n't we drive around the corner '' ?
# drive They could walk , ride on a bus or be driven .
# drive Three separate amplifiers then drive a 21 - inch tricolor tube .
# drive drive a car or bus
# drive She is driven by her passion
# drive drive the ball far out into the field
# drive My new truck drives well
# drive He drives a bread truck
# drive drive the cows into the barn
# drive We drive the turnpike to work
# drive drive a golf ball
# drive drive a ball
# drive drive a tunnel
# drive The amplifier drives the tube
# drive drive the forest
# drive drive the game
# drive He drives me mad
# drop He conditions dropped
# drop Drop oil into the mixture
# drop Drop down a tree
# drop The key was dropped for the male singer
# drop How could I drop that typo?
# drop Drop money
# drop Yuck honey is that old Play Doh we ha have to throw that away
# drop Gavin sank down again into his chair and began to rock .
# drop The light dropped from the ceiling
# drop They dropped her after she had a child out of wedlock
# drop Don't drop the dishes
# drop the bombs are dropping on enemy targets
# drop Stock prices dropped
# drop drop him from the Republican ticket
# drop drop a hint
# drop drop a lawsuit
# drop drop off the passengers at the hotel
# drop The Giants dropped 11 of their first 13
# drop She dropped acid when she was a teenager
# drop New Englanders drop their post-vocalic r's
# drop She dropped into army jargon
# drop shop til you drop
# drop The cow dropped her calf this morning
# dry dry land
# dry dry paint
# dry the dry vote led by preachers and bootleggers
# dry a dry cow
# dry a dry white burgundy
# dry a dry cough
# dry dry humor
# dry dry sobs
# dry a dry book
# dry dry weight
# dry a dry run
# dry dry facts
# dry dry toast
# dry a very dry martini is almost straight gin
# dry a dry greeting
# dry he's been dry for ten years
# dryer you got a washing machine and dryer didn't you
# duck And he ends his round with a duck
# duck There was a hole in my duck cloth so I got rained on
# duck Can you see the yellow duck?
# duck Duck soup will do
# dump He dumped his opponent
# dump we try not to dump our books
# dump should we dump all the pieces out
# dump No dumping in these woods!
# dump The company dumped him after many years of service
# dump The truck dumped the garbage in the street
# ear I ate an ear of corn
# ear I don't think it's behind your ear, is it?
# ear The smallest bones are hidden deep inside our ears
# ear he had a keen ear
# ear he tried to get her ear
# eat This car eats a lot of gas
# eat What did you eat for dinner last night?
# eat She was eating a banana
# eat We did not eat until 10 P.M. because there were so many phone calls
# eat What's eating you?
# eat This dog doesn't eat certain kinds of meat
# egg she kicked him in the balls and got away
# egg The birds have eggs in their nests
# egg Which comes first the chicken or the egg
# elephant An Elephant like you wouldn't understand
# elephant He rewarded the elephant with a big peanut
# empty an empty glass
# empty empty promises
# empty after skipped lunch the men were empty by suppertime
# empty after the violent argument he felt empty
# eye Mr. Jack cried when the brush tipped his hat down over his eyes .
# eye they were in the eye of the storm
# eye she has an eye for fresh talent
# eye he tried to catch her eye
# eye the thread wouldn't go through the eye
# face I couldn't believe her face
# face The face of a hammer
# face This face of the building is unfinished
# face I prefer bold face font
# face Look at the face on that little duckie
# face Do a really angry face and don't smile
# face an angry face
# face he washed his face
# face the face of the city is changing
# face he looked out at a roomful of faces
# face he dealt the cards face down
# fix Maybe the farmer can fix it with a screwdriver
# fix fix breakfast for the guests, please
# fix she fixed her gaze on the man
# fix Let's fix the date for the party!
# fix fix a race
# fix I was fixing to leave town after I paid the hotel bill
# fix let's fix the picture to the frame
# fix That'll fix him good!
# fix fix your eyes on this spot
# fix fix the variables
# flag You can buy flag at the hardware store for stepping stones
# flag no_example
# flag What a beautiful field of flags
# flag This is our flag ship newspaper
# flag The flag on the 18th hole
# flag That's a flag on a castle
# flag When the train's ready to go he waves his flag
# flower no_example
# flower This same flower that smiles today tomorrow will be dying '' .
# flower In the villages people lined up to give us flowers .
# food I need some brain food for my essay
# food Many food and beverage companies are already on a highly planned basis .
# food food and drink
# foot no_example
# foot You're completely skipping the second foot here
# foot Joey's mother nibbles grass she uses her short front arms and big back feet to hop-step forward
# foot The broad foot of the chiton anchors it to the shore
# foot In Hilo Bay they were from 21 to 26 feet high .
# foot armored from head to foot
# foot curled up on the foot of the bed
# foot he followed on foot
# foot one foot of the chair was on the carpet
# foot he stood at the foot of the tower
# foot there came ten thousand horsemen and as many fully-armed foot
# fork There is a fork in the company to Europe
# fork There is a stain in the fork of this jeans
# fork I'm gonna use a fork to eat it
# fork It's a spade and a fork isn't it
# fork they took the south fork
# frog You are a frog
# frog The pillow has a beuitiful frog and golden tassels
# frog Hoppity hop he jumps like a frog
# full full summer
# full gave full attention
# full a full glass
# full full tones
# full a full game
# full a full stomach
# full gives full measure
# full a full skirt
# game We hunted some game over the weekend
# game This is a game point
# game Let's cook the game we hunted in the woods
# game you need four people to play this game
# game the game lasted two hours
# game they played word games
# game the game is 6 all
# game the child received several games for his birthday
# game he's in the plumbing game
# game for actors, memorizing lines is no game
# game I saw through his little game from the start
# garage The bus is going to reverse into the garage isn't it
# garage The bombs are as harmless as an automobile in a garage .
# garbage This information is garbage
# garbage There are a lot of leftover garbage from thanksgiving
# garbage she tossed the moldy bread into the garbage
# garden Those are stairs that go in to the rose garden
# garden And indeed the young garden beans were brackish in her mouth .
# garden She was looking out at the garden .
# gentle of gentle blood
# gentle a gentle old horse, docile and obedient
# gentle gentle rain
# gentle a gentle slope
# gentle a gentle reprimand
# gentle the gentle touch of her hand
# gentle a gentle voice
# get John got four daughters
# get Get the attention of the waiter
# get She got the mood just right in her photographs
# get He drew a base on balls
# get What are you getting at?
# get She got a fracture in the accident
# get She got the bus just as it was leaving
# get The cat got the goldfish
# get The Brazilian team got 4 goals
# get This question really got me
# get I got nothing but trouble
# get She got a fracture in the accident
# get He'll get a cold
# get They're trying to get the fox
# get Gonna get a smack in a bit
# get His eyes get big and soft
# get Do you wanna get out of here?
# get Another memo for sightseers : bring your camera along to museums .
# get It contracts with outside repair garages for much of the latter work .
# get `` We get strange orders '' .
# get Just about to get their asses kicked into hut Seven .
# get Somehow our contemporary Moloch must be induced to see reason .
# get She didn't get to Chicago until after midnight
# get It must be getting more serious
# get did you get it?
# get She didn't get his name when they met the first time
# get get an idea
# get The operator couldn't get Kobe because of the earthquake
# get What do you get when you add up these numbers?
# get You cannot get water out of a stone
# get What did you get at the toy store?
# get Her childish behavior really get to me
# wash Soil redeposition is evaluated by washing clean swatches with the dirty ones .
# wash The swollen river washed away the footbridge
# wash Does this material wash?
# wash This silly excuse won't wash in traffic court
# wash he washed the dirt from his coat
# wash The river washed a ravine into the mountainside
# wash The cat washes several times a day
# watch He was an excellent watch for large events
# watch the security forces have been_keeping a close watch on_our activities
# watch He took the last watch before down
# watch When a Jew dies, a watch is kept over the body
# watch His watch told him he was still early .
# watch `` Under arms day and night , watch and watch about .
# water They poured water over their catcher 's face .
# water the water sign of Pisces ( February 18 - March 20 ) .
# water they invaded our territorial waters
# water the child had to make water
# water he asked for a drink of water
# water the town debated the purification of the water supply
# wet no_example
# wet a wet bathing suit
# wet wet paint
# wet a wet candidate running on a wet platform
# wet a wet nurse
# wet a wet cargo
# white She likes her coffee white
# white lips white with terror
# white wide white margins
# white as white as fresh snow
# white voting patterns within the white population
# white in shining white armor
# white a white Christmas
# white under segregation there were even white restrooms and white drinking fountains
# white white flames
# white that's white of you
# white the white hairs of old age
# white white nights
# wind he got wind on the stock market
# wind The clarinet is a wind instruments
# wind Have you got wind now
# wind trees bent under the fierce winds
# wind the winds of change
# wind the collision knocked the wind out of him
# wind that's a lot of wind
# wind he put the key in the old clock and gave it a good wind
# window There are small windows in the bank to protect employees
# window The computer crashed because there were too many windows open
# window My car windows are gonna need to be rolled down
# window He stared out the window .
# window he could see them through a window in the trees
# window the expanded window will give us time to catch the thieves
# window he stuck his head in the window
# window the ball shattered the window
# windy windy schemes for getting rich
# windy a windy bluff
# windy long-winded (or windy) speakers
# windy a windy dash home
# wipe wipe the blackboard
# wolf He is a total wolf, he just cares about gaining the most for himself
# wolf Be careful of the wolves in the bar
# wolf those are very fast animals, a wolf
# wolf no_example
# wolf no_example
# work Work the soil
# work Work the metal into a sword
# work Work the phones
# work I cannot work a miracle
# work My personal trainer works me hard
# work She knows how to work the system
# work The vintner worked the wine in big oak vats
# work This old radio doesn't work anymore
# work The artist's work influenced the young painter
# work work the clay until it is soft
# work work one's way through the crowd
# work this unpleasant situation isn't going to work itself out
# work The wine worked
# work I will work hard to improve my grades
# work Is your husband working again?
# work The voting process doesn't work as well as people thought
# work work stone into tools
# work She works the night clubs
# work work your way through every problem or task
# work His fingers worked with tension
# work he is working his servants hard
# work This dough does not work easily
# work This pilot works the controls
# work The rock musician worked the crowd of young girls into a frenzy
# work the political candidate worked the crowds
# work work the raisins into the dough
# work The stitches of the hem worked loose after she wore the skirt many times
# write Beethoven wrote nine symphonies
# write b=Boot-up instructions are written on the hard disk
# write Here do you wanna write your name
# write And everyone went to work to learn the parts which he wrote .
# write writes : Do steam baths have any health value ?
# write We would write to one another and make a definite plan .
# write I can see it from this window where I write .
# write How many books did Georges Simenon write?
# write Please write to me every week
# write She writes code faster than anybody else
# yard I need about a cubic yard of concrete
# yard We put the logs in the yard
# yard We keep the chickens in the yard
# yard In the train yard, engines hook up to coaches and freight cars
# yard I need 3 yards of fabric
# yard Some yards are used to display flags
# yard He boomed a 280 - yard drive .
# yard it was a small house with almost no yard
# yard they opened a repair yard on the edge of town
# yellow He's too yellow to go skydiving
# yellow His liver is going bad so he's going yellow
# yellow `` I 'm not saying you 're yellow .
# yellow yellow press
# yellow yellowed parchment
# yellow the little yellow stain of treason
# yogurt This is the low fat yogurt we need to get the full fat yogurt for you
# yucky I think rats are yucky
# zebra This zebra has black and white stripes
# zipper The zipper on my jacket broke

# %%
examples_df.groupby(by=['contains_word']).size().reset_index()
# Out:
#    contains_word     0
# 0          False   450
# 1           True  2437

# %%
examples_df[examples_df['lemma']=='green']
# Out:
#       lemma       sense_name  \
# 1308  green  fleeceable.s.01
# 1309  green       green.a.02
# 1310  green       green.a.03
# 1311  green       green.s.01
# 1312  green       green.s.04
#
#                                              definition  \
# 1308               naive and easily deceived or tricked
# 1309  concerned with or supporting or in conformity ...
# 1310            not fully developed or mature; not ripe
# 1311  of the color between blue and yellow in the co...
# 1312                         looking pale and unhealthy
#
#                                                 example    example_source
# 1308  At that early age she had been gullible and in...  new_hand_written
# 1309                                         no_example        no_example
# 1310                               fried green tomatoes           wordnet
# 1311                                       a green tree           wordnet
# 1312                               you're looking green           wordnet

# %%
# Move to a google sheet to fill the rest
examples_df.to_csv("sense_examples_from_corpora.csv", index=False)

# %% [markdown]
# Estimates Counts

# %%
num_senses = len(cdi_wordnet_df)
num_words = len(set(cdi_wordnet_df.lemma))
num_estimations = 15
num_estimations_from_part = 50
print(f"{num_senses} senses for {num_words} words")
print(f"    {num_estimations} estimations per senses")
print(f"{num_senses*num_estimations} estimations needed")
print(f"    {num_estimations_from_part} estimations per participant")
print(f"{num_senses*num_estimations/num_estimations_from_part} participants needed")
# Out:
# 2887 senses for 439 words
#     15 estimations per senses
# 43305 estimations needed
#     50 estimations per participant
# 866.1 participants needed

# %%
cdi_wordnet_df.groupby(by=['lemma'])['sense_name'].agg('nunique').reset_index().hist('sense_name', bins=60)

# %%
len(set(sense_survey.word_sense_combo))

# %%
cdi_wordnet_df['sense_pos'] = cdi_wordnet_df.sense_name.apply(lambda sense_name: sense_name.split(".")[1])

# %%
cdi_wordnet_df = pd.merge(cdi_wordnet_df, cdi_items[['lexical_class', 'fixed_lemma']],
                         left_on='lemma', right_on='fixed_lemma', how='left')

# %%
cdi_wordnet_df.lexical_class = cdi_wordnet_df.lexical_class.replace('nouns', 'n')
cdi_wordnet_df.lexical_class = cdi_wordnet_df.lexical_class.replace('verbs', 'v')
cdi_wordnet_df.lexical_class = cdi_wordnet_df.lexical_class.replace('adjective', 'a')

# %%
cdi_wordnet_df[cdi_wordnet_df['sense_pos']==cdi_wordnet_df['lexical_class']]

# %%
cdi_wordnet_df[cdi_wordnet_df['lemma']=='water']

# %%
84840/60

# %%
cdi_wordnet_df.lemma.value_counts().hist(bins=30)

# %%
set(sense_survey.wordnet_sense)

# %%
cdi_wordnet_df.lemma.value_counts().hist()

# %%
cdi_items

# %%
set(cdi_items.fixed_lemma) - set(cdi_wordnet_df.lemma)

# %%
# match from wordsense project <3

# qualities of a good example
# 3 or more words in the utterance
# less than 7 words in the utterance
# descriptive <- hard to quantify

# %%
# What to do about mine and IT - technically polysemous, but across the pronoun vs other noun boundary.
# Do we want to show all senses for a single word, even across pos
